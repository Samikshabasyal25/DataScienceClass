# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt

months=["Jan", 'Feb','Mar','Apr','May' ]
sales=[100,120,150,130,180]

plt.subplot(2,2,1)
plt.plot(months,sales)
plt.title("Line Chart")

plt.subplot(2,2,2)
plt.bar(months,sales)
plt.title("Bar Chart")

plt.subplot(2,2,3)
plt.scatter(range(5),sales)
plt.title("Scatter Plot")

plt.subplot(2,2,4)
plt.hist(sales)
plt.title("Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Figure and Axes

# %%
fig,ax=plt.subplots()
ax.plot(months,sales)

ax.set_title("Monthly Sales")
ax.set_xlabel("Month")
ax.set_ylabel("Sales")

plt.show()

# %%
fig,axes=plt.subplots(2,2)

axes[0,0].plot(months,sales)
axes[0,0].set_title("Line")

axes[0,1].bar(months,sales)
axes[0,1].set_title("Bar")

axes[1,0].scatter(range(5),sales)
axes[1,0].set_title("Scatter")

axes[1,1].hist(sales)
axes[1,1].set_title("Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Figure

# %%
fig,axes=plt.subplots(2,2)

axes[0,0].plot(months,sales)
axes[0,0].set_title("Line")

axes[0,1].bar(months,sales)
axes[0,1].set_title("Bar")

axes[1,0].scatter(range(5),sales)
axes[1,0].set_title("Scatter")

axes[1,1].hist(sales)
axes[1,1].set_title("Histogram")

plt.tight_layout()

plt.savefig("my_charts.png",dpi=300,bbox_inches="tight")
plt.show()

# %% [markdown]
# # Pandas Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    
    "Months":["Jan", 'Feb','Mar','Apr','May' ],
    "Sales":[100,120,150,130,180]
}
df=pd.DataFrame(data)

df.plot(
    x="Months",
    y="Sales",
    kind="line"
)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    
    "Months":["Jan", 'Feb','Mar','Apr','May' ],
    "Sales":[100,120,150,130,180]
}
df=pd.DataFrame(data)

df.plot(
    x="Months",
    y="Sales",
    kind="bar"
)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    
    "Months":["Jan", 'Feb','Mar','Apr','May' ],
    "Sales":[100,120,150,130,180]
}
df=pd.DataFrame(data)

df.plot(
    x="Months",
    y="Sales",
    kind="hist"
)
plt.show()

# %% [markdown]
# # Seaborn

# %%
#Seaborn is a Python Visualization library built on top of Matplotlib
#It makes statistical Visualizaton easier.

# %%
import seaborn as sns
df=sns.load_dataset("tips")
#print(df)
print(df.head())
# print(df.info())
# print(df.tail())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Seaborn Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset("tips")

sns.scatterplot(
    data=df,
    x="total_bill",
    y="tip"
)
plt.show()

# %% [markdown]
# # Scatter Plot with Category

# %%
# hue = Use Different visual groups based on a categorical variable.

# %%
sns.scatterplot(
    data=df,
    x="total_bill",
    y="tip",
    hue="sex"
)
plt.show()

# %% [markdown]
# # Seaborn Line Plot

# %%
sns.lineplot(
    data=df,
    x="size",
    y="tip"
)

plt.show()

# %%
sns.barplot(
    data=df,
    x="day",
    y="total_bill",
    errorbar=None
)

plt.show()

# %% [markdown]
# # Count Plot

# %%
#A count plot is useful when we want to know how many observation belongs to each category
# How many records are from
#Thrusdat?
#Friday?....so on
sns.countplot(
    data=df,
    x="day"
)
plt.show()

# %% [markdown]
# # Box plot with Seaborn

# %%
sns.boxplot(
    data=df,
    x="day",
    y="total_bill"
)
plt.show()
